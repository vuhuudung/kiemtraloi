# %%
from openai import OpenAI
from checker.ai.openai_word_checker import OpenAIWordChecker

client = OpenAI(api_key="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")

checker = OpenAIWordChecker(client)

print(
    checker.check_words(
        ["Cônng", "Thựcc", "kkhi", "UBND"],
        "Cônng tác Thựcc hiện nhiệm vụ kkhi UBND xã triển khai."
    )
)
# Out:
# {'Cônng': {'status': 'sai', 'suggestion': 'Công'}, 'Thựcc': {'status': 'sai', 'suggestion': 'Thực'}, 'kkhi': {'status': 'sai', 'suggestion': 'khi'}, 'UBND': {'status': 'đúng', 'suggestion': ''}}
